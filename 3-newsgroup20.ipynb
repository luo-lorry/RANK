# %%
import torch

# %%
data = torch.load('model_and_results.pt')#, map_location=torch.device('cpu'))
scores = data['logits']
targets = data['labels']
print(scores.shape, targets.shape)
# Out:
# torch.Size([7532, 20]) torch.Size([7532])

# %%
from torchcp.classification.predictors import SplitPredictor
from torchcp.classification.scores import THR, APS, SAPS, RAPS, THRRANK
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def evaluation(cal_x, cal_y, test_x, test_y, score_function, score_function_param=None,
                        alpha=0.01, dataset='NLP'):
    print(
        f"Experiment--Data : {dataset}, Score : {score_function.__name__}, Predictor : SplitPredictor, Alpha : {alpha}")
    
    if not torch.is_tensor(cal_x):
        cal_x = torch.from_numpy(cal_x).double()
        cal_y = torch.from_numpy(cal_y).long()
        test_x = torch.from_numpy(test_x).double()
        test_y = torch.from_numpy(test_y).long()
        
    if score_function_param is not None:
        if isinstance(score_function_param, tuple):
            predictor = SplitPredictor(score_function(*score_function_param))
        else:
            predictor = SplitPredictor(score_function(score_function_param))
    else:
        predictor = SplitPredictor(score_function())

    predictor.calculate_threshold(cal_x, cal_y, alpha)
    prediction_sets = []
    labels_list = []
    prediction_sets = predictor.predict_with_logits(test_x)
    # prediction_sets.append(prediction_sets_batch)
    labels_list = test_y
    
    metrics = predictor.evaluate_scores(prediction_sets, torch.Tensor(labels_list).long(), alpha)
    coverage = np.round(metrics['Coverage_rate'], 3)
    size = np.round(metrics['Average_size'], 3)
    sscv = np.round(metrics['SSCV'], 3)
    print(f"Coverage: {coverage}; Size: {size}; SSCV: {sscv}")

    # Create a DataFrame to store the evaluation metrics
    metrics_df = pd.DataFrame({'Data': [dataset],
                               'Alpha': [alpha],
                               'Score Function': [score_function.__name__],
                               'Coverage': [coverage],
                               'Size': [size], 
                               'SSCV': [sscv]})
    return metrics_df

# %%
alphas = np.linspace(0.1, 0.3, 11)
score_functions = [THRRANK, APS, RAPS, SAPS] #
score_function_params = {RAPS: (0.2, 2), SAPS: 0.2}
num_repetitions = 100
results_df = pd.DataFrame(columns=['Data', 'Alpha', 'Score Function', 'Coverage', 'Size', 'SSCV'])

name = 'newsgroup20'
for alpha in alphas:
    index = np.arange(len(scores))

    for score_function in score_functions:
        coverage_values = []
        size_values = []
        sscv_values = []
        for run_id in range(num_repetitions):
            np.random.shuffle(index)
            n = len(scores) // 2
            cal_scores = scores[index][:n]
            val_scores = scores[index][n:]
            cal_targets = targets[index][:n]
            val_targets = targets[index][n:]

            if score_function in score_function_params:
                score_function_param = score_function_params[score_function]
            else:
                score_function_param = None

            metrics_df = evaluation(cal_scores, cal_targets, val_scores, val_targets, score_function, score_function_param, alpha=alpha, dataset=name)
            coverage_values.append(metrics_df['Coverage'].values[0])
            size_values.append(metrics_df['Size'].values[0])
            sscv_values.append(metrics_df['SSCV'].values[0])
            

        # Calculate the median-of-means for coverage and size
        median_coverage = pd.Series(coverage_values).mean()
        median_size = pd.Series(size_values).mean()
        median_sscv = pd.Series(sscv_values).mean()

        # Add the median-of-means results to the DataFrame
        results_df.loc[len(results_df)] = [name, alpha,
                                           f"Ours ({score_function})" if isinstance(score_function,
                                                                                    str) else score_function.__name__,
                                           median_coverage, median_size, median_sscv]
# Out:
# Experiment--Data : newsgroup20, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size:
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 3.317; SSCV: 0.102
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 3.585; SSCV: 0.07
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 3.285; SSCV: 0.108
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 3.495; SSCV: 0.074
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 3.484; SSCV: 0.08
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 3.426; SSCV: 0.099
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 3.118; SSCV: 0.131
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 3.361; SSCV: 0.096
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 3.543; SSCV: 0.08
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 3.393; SSCV: 0.093
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 3.584; SSCV: 0.075
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 3.28; SSCV: 0.107
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 3.23; SSCV: 0.111
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 3.365; SSCV: 0.092
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 3.463; SSCV: 0.075
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.911; Size: 3.694; SSCV: 0.06
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 3.249; SSCV: 0.103
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.91; Size: 3.723; SSCV: 0.064
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 3.273; SSCV: 0.117
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 3.24; SSCV: 0.11
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.882; Size: 2.987; SSCV: 0.139
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 3.346; SSCV: 0.097
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 3.352; SSCV: 0.1
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.91; Size: 3.695; SSCV: 0.063
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# ...
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.7; Size: 1.306; SSCV: 0.454
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.697; Size: 1.304; SSCV: 0.401
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.694; Size: 1.291; SSCV: 0.364
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.693; Size: 1.294; SSCV: 0.405
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.715; Size: 1.313; SSCV: 0.394
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.7; Size: 1.317; SSCV: 0.412
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.707; Size: 1.3; SSCV: 0.486
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.709; Size: 1.308; SSCV: 0.454
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.7; Size: 1.302; SSCV: 0.417
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.684; Size: 1.281; SSCV: 0.408
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.702; Size: 1.31; SSCV: 0.416
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.707; Size: 1.309; SSCV: 0.413
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.692; Size: 1.289; SSCV: 0.383
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.709; Size: 1.302; SSCV: 0.423
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.715; Size: 1.312; SSCV: 0.391
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.687; Size: 1.285; SSCV: 0.459
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.708; Size: 1.305; SSCV: 0.404
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.704; Size: 1.29; SSCV: 0.441
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.695; Size: 1.29; SSCV: 0.396
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.708; Size: 1.313; SSCV: 0.438
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.697; Size: 1.314; SSCV: 0.452
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.711; Size: 1.304; SSCV: 0.475
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.728; Size: 1.334; SSCV: 0.409
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.696; Size: 1.307; SSCV: 0.422
# Experiment--Data : newsgroup20, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.694; Size: 1.309; SSCV: 0.38
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.655; Size: 1.328; SSCV: 0.373
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.667; Size: 1.336; SSCV: 0.367
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.695; Size: 1.381; SSCV: 0.341
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.706; Size: 1.377; SSCV: 0.259
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.71; Size: 1.386; SSCV: 0.267
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.701; Size: 1.384; SSCV: 0.323
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.697; Size: 1.396; SSCV: 0.331
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.694; Size: 1.366; SSCV: 0.375
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.701; Size: 1.394; SSCV: 0.324
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.699; Size: 1.381; SSCV: 0.316
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.687; Size: 1.374; SSCV: 0.327
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.696; Size: 1.366; SSCV: 0.302
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.712; Size: 1.382; SSCV: 0.337
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.68; Size: 1.359; SSCV: 0.362
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.703; Size: 1.388; SSCV: 0.295
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.706; Size: 1.389; SSCV: 0.332
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.705; Size: 1.382; SSCV: 0.365
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.705; Size: 1.391; SSCV: 0.295
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.697; Size: 1.385; SSCV: 0.329
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.681; Size: 1.347; SSCV: 0.326
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.694; Size: 1.357; SSCV: 0.304
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.707; Size: 1.385; SSCV: 0.297
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.693; Size: 1.384; SSCV: 0.331
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.71; Size: 1.378; SSCV: 0.277
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.689; Size: 1.397; SSCV: 0.32
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.695; Size: 1.364; SSCV: 0.317
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.683; Size: 1.362; SSCV: 0.326
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.713; Size: 1.415; SSCV: 0.296
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.691; Size: 1.379; SSCV: 0.367
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.703; Size: 1.371; SSCV: 0.293
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.683; Size: 1.37; SSCV: 0.292
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.701; Size: 1.401; SSCV: 0.33
# Experiment--Data : newsgroup20, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.3
# Coverage: 0.711; Size: 1.381; SSCV: 0.335

# %%
colors = plt.get_cmap("tab10")
names = ['THRRANK', 'APS', 'RAPS', 'SAPS']
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24, 6))

# Plot Size vs. Coverage
for idx, score_function in enumerate(score_functions):
    result = results_df[results_df['Score Function'] == names[idx]]
    if score_function == THRRANK:
        ax1.plot(result['Coverage'], result['Size'], color=colors(idx), linestyle='-', marker='o', label="RANK (Ours)")
    else:
        ax1.plot(result['Coverage'], result['Size'], color=colors(idx), linestyle='-', marker='o', label=names[idx])

ax1.set_xlabel('Coverage', fontsize=14)
ax1.set_ylabel('Size', fontsize=14)
ax1.set_title('Size vs. Coverage', fontsize=18)
ax1.legend(loc='upper left', fontsize=14)
ax1.grid(True)

# Plot Coverage vs. Alpha
for idx, score_function in enumerate(score_functions):
    result = results_df[results_df['Score Function'] == names[idx]]
    if score_function == THRRANK:
        ax2.plot(result['Alpha'], result['Coverage'], color=colors(idx), linestyle='-', marker='o', label="RANK (Ours)")
    else:
        ax2.plot(result['Alpha'], result['Coverage'], color=colors(idx), linestyle='-', marker='o', label=names[idx])

# Generate the theoretical line 1 - alpha
theoretical_coverage = [1 - alpha for alpha in alphas]
ax2.plot(alphas, theoretical_coverage, color='black', linestyle='--', label='Theoretical (1 - $\\alpha$)')

ax2.set_xlabel('$\\alpha$', fontsize=14)
ax2.set_ylabel('Coverage', fontsize=14)
ax2.set_title('Coverage vs. $\\alpha$', fontsize=18)
ax2.legend(loc='lower left', fontsize=14)
ax2.grid(True)

# Plot Alpha vs. SSCV
for idx, score_function in enumerate(score_functions):
    result = results_df[results_df['Score Function'] == names[idx]]
    if score_function == THRRANK:
        ax3.plot(result['Alpha'], result['SSCV'], color=colors(idx), linestyle='-', marker='o', label="RANK (Ours)")
    else:
        ax3.plot(result['Alpha'], result['SSCV'], color=colors(idx), linestyle='-', marker='o', label=names[idx])

ax3.set_xlabel('$\\alpha$', fontsize=14)
ax3.set_ylabel('SSCV', fontsize=14)
ax3.set_title('SSCV vs. $\\alpha$', fontsize=18)
ax3.legend(loc='upper left', fontsize=14)
ax3.grid(True)

plt.tight_layout()
plt.show()

fig.savefig('newsgroup.pdf')

# %%
results_df.to_csv('newsgroup.csv')
