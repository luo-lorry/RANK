# %%
import torch

# %%
data = torch.load('model_and_results-2.pt')#, map_location=torch.device('cpu'))
scores = data['logits']
targets = data['labels']
print(scores.shape, targets.shape)
# Out:
# torch.Size([2000, 6]) torch.Size([2000])

# %%
from torchcp.classification.predictors import SplitPredictor
from torchcp.classification.scores import THR, APS, SAPS, RAPS, THRRANK
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def evaluation(cal_x, cal_y, test_x, test_y, score_function, score_function_param=None,
                        alpha=0.01, dataset='NLP'):
    print(
        f"Experiment--Data : {dataset}, Score : {score_function.__name__}, Predictor : SplitPredictor, Alpha : {alpha}")
    
    if not torch.is_tensor(cal_x):
        cal_x = torch.from_numpy(cal_x).double()
        cal_y = torch.from_numpy(cal_y).long()
        test_x = torch.from_numpy(test_x).double()
        test_y = torch.from_numpy(test_y).long()
        
    if score_function_param is not None:
        if isinstance(score_function_param, tuple):
            predictor = SplitPredictor(score_function(*score_function_param))
        else:
            predictor = SplitPredictor(score_function(score_function_param))
    else:
        predictor = SplitPredictor(score_function())

    predictor.calculate_threshold(cal_x, cal_y, alpha)
    prediction_sets = []
    labels_list = []
    prediction_sets = predictor.predict_with_logits(test_x)
    # prediction_sets.append(prediction_sets_batch)
    labels_list = test_y
    
    metrics = predictor.evaluate_scores(prediction_sets, torch.Tensor(labels_list).long(), alpha)
    coverage = np.round(metrics['Coverage_rate'], 3)
    size = np.round(metrics['Average_size'], 3)
    sscv = np.round(metrics['SSCV'], 3)
    print(f"Coverage: {coverage}; Size: {size}; SSCV: {sscv}")

    # Create a DataFrame to store the evaluation metrics
    metrics_df = pd.DataFrame({'Data': [dataset],
                               'Alpha': [alpha],
                               'Score Function': [score_function.__name__],
                               'Coverage': [coverage],
                               'Size': [size], 
                               'SSCV': [sscv]})
    return metrics_df

# %%
results_df.shape
# Out:
# (44, 6)

# %%
alphas = np.linspace(0.1, 0.3, 11)
score_functions = [THRRANK, APS, RAPS, SAPS] #
score_function_params = {RAPS: (0.2, 2), SAPS: 0.2}
num_repetitions = 100
results_df = pd.DataFrame(columns=['Data', 'Alpha', 'Score Function', 'Coverage', 'Size', 'SSCV'])

name = 'carer'
for alpha in alphas:
    index = np.arange(len(scores))

    for score_function in score_functions:
        coverage_values = []
        size_values = []
        sscv_values = []
        for run_id in range(num_repetitions):
            np.random.shuffle(index)
            n = len(scores) // 2
            cal_scores = scores[index][:n]
            val_scores = scores[index][n:]
            cal_targets = targets[index][:n]
            val_targets = targets[index][n:]

            if score_function in score_function_params:
                score_function_param = score_function_params[score_function]
            else:
                score_function_param = None

            metrics_df = evaluation(cal_scores, cal_targets, val_scores, val_targets, score_function, score_function_param, alpha=alpha, dataset=name)
            coverage_values.append(metrics_df['Coverage'].values[0])
            size_values.append(metrics_df['Size'].values[0])
            sscv_values.append(metrics_df['SSCV'].values[0])
            

        # Calculate the median-of-means for coverage and size
        median_coverage = pd.Series(coverage_values).median()
        median_size = pd.Series(size_values).median()
        median_sscv = pd.Series(sscv_values).median()

        # Add the median-of-means results to the DataFrame
        results_df.loc[len(results_df)] = [name, alpha,
                                           f"Ours ({score_function})" if isinstance(score_function,
                                                                                    str) else score_function.__name__,
                                           median_coverage, median_size, median_sscv]
# Out:
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 0.932; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.888; Size: 0.914; SSCV: 0.012
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 0.922; SSCV: 0.008
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 0.927; SSCV: 0.004
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 0.931; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.887; Size: 0.917; SSCV: 0.013
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 0.916; SSCV: 0.015
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.887; Size: 0.92; SSCV: 0.013
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 0.934; SSCV: 0.004
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.929; Size: 0.962; SSCV: 0.029
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 0.921; SSCV: 0.01
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 0.93; SSCV: 0.0
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 0.923; SSCV: 0.004
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 0.925; SSCV: 0.002
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 0.919; SSCV: 0.01
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 0.925; SSCV: 0.008
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.922; Size: 0.96; SSCV: 0.022
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.88; Size: 0.91; SSCV: 0.02
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 0.93; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.921; Size: 0.955; SSCV: 0.021
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 0.911; SSCV: 0.017
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.919; Size: 0.951; SSCV: 0.019
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 0.924; SSCV: 0.007
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 0.932; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 0.911; SSCV: 0.017
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 0.933; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 0.912; SSCV: 0.017
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 0.944; SSCV: 0.015
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.916; Size: 0.947; SSCV: 0.016
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 0.949; SSCV: 0.015
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.917; Size: 0.952; SSCV: 0.017
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.922; Size: 0.955; SSCV: 0.022
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.925; Size: 0.96; SSCV: 0.025
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.887; Size: 0.923; SSCV: 0.013
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 0.925; SSCV: 0.004
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 0.933; SSCV: 0.002
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 0.945; SSCV: 0.003
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.878; Size: 0.903; SSCV: 0.022
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.889; Size: 0.923; SSCV: 0.011
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 0.951; SSCV: 0.014
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 0.922; SSCV: 0.01
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.876; Size: 0.908; SSCV: 0.024
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 0.945; SSCV: 0.009
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 0.929; SSCV: 0.008
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.913; Size: 0.942; SSCV: 0.013
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 0.935; SSCV: 0.0
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.895; Size: 0.928; SSCV: 0.005
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.891; Size: 0.926; SSCV: 0.009
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 0.938; SSCV: 0.004
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 0.926; SSCV: 0.008
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.886; Size: 0.919; SSCV: 0.014
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 0.944; SSCV: 0.014
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.884; Size: 0.906; SSCV: 0.016
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 0.951; SSCV: 0.014
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 0.921; SSCV: 0.006
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 0.936; SSCV: 0.002
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 0.928; SSCV: 0.004
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.887; Size: 0.912; SSCV: 0.013
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 0.925; SSCV: 0.007
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 0.923; SSCV: 0.006
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 0.934; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 0.939; SSCV: 0.005
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.921; Size: 0.96; SSCV: 0.021
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 0.934; SSCV: 0.003
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 0.939; SSCV: 0.003
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.908; Size: 0.939; SSCV: 0.008
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.921; Size: 0.957; SSCV: 0.021
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 0.949; SSCV: 0.015
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.918; Size: 0.955; SSCV: 0.018
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.916; Size: 0.951; SSCV: 0.016
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.93; Size: 0.962; SSCV: 0.03
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.926; Size: 0.96; SSCV: 0.026
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.868; Size: 0.895; SSCV: 0.032
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 0.924; SSCV: 0.01
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 0.924; SSCV: 0.01
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.878; Size: 0.907; SSCV: 0.022
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 0.928; SSCV: 0.007
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 0.933; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 0.914; SSCV: 0.015
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.93; Size: 0.967; SSCV: 0.03
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 0.924; SSCV: 0.006
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 0.906; SSCV: 0.017
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.88; Size: 0.907; SSCV: 0.02
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.912; Size: 0.946; SSCV: 0.012
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.884; Size: 0.919; SSCV: 0.016
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 0.933; SSCV: 0.002
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 0.937; SSCV: 0.002
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 0.918; SSCV: 0.015
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.88; Size: 0.906; SSCV: 0.02
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 0.933; SSCV: 0.002
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 0.939; SSCV: 0.005
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 0.932; SSCV: 0.002
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.872; Size: 0.901; SSCV: 0.028
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 0.915; SSCV: 0.017
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 0.932; SSCV: 0.003
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 0.934; SSCV: 0.003
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.913; Size: 0.951; SSCV: 0.013
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 0.943; SSCV: 0.009
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.911; Size: 0.945; SSCV: 0.011
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.878; Size: 0.916; SSCV: 0.022
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.889; Size: 1.02; SSCV: 0.081
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 1.018; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 1.037; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.038; SSCV: 0.082
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.889; Size: 1.039; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.913; Size: 1.051; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.927; Size: 1.079; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 1.032; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.039; SSCV: 0.09
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 1.047; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.886; Size: 1.03; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 1.027; SSCV: 0.08
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.888; Size: 1.007; SSCV: 0.078
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.908; Size: 1.063; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.881; Size: 1.032; SSCV: 0.092
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.887; Size: 1.025; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.907; Size: 1.047; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.06; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.874; Size: 1.004; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.88; Size: 1.023; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.03; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 1.045; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.873; Size: 1.015; SSCV: 0.082
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.05; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.025; SSCV: 0.09
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.028; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.912; Size: 1.048; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 1.064; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 1.054; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.05; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.05; SSCV: 0.092
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.908; Size: 1.062; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.864; Size: 0.999; SSCV: 0.09
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.057; SSCV: 0.084
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 1.037; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.918; Size: 1.077; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.923; Size: 1.073; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.04; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.891; Size: 1.02; SSCV: 0.082
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 1.045; SSCV: 0.083
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 1.028; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.927; Size: 1.071; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 1.041; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 1.021; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 1.051; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.037; SSCV: 0.082
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.895; Size: 1.03; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.874; Size: 1.015; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.895; Size: 1.006; SSCV: 0.075
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.886; Size: 1.024; SSCV: 0.09
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 1.053; SSCV: 0.092
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 1.043; SSCV: 0.075
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.88; Size: 1.024; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.884; Size: 1.028; SSCV: 0.083
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.908; Size: 1.042; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.916; Size: 1.053; SSCV: 0.082
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.891; Size: 1.026; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 1.04; SSCV: 0.082
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.05; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.91; Size: 1.044; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.039; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.867; Size: 1.002; SSCV: 0.09
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.884; Size: 1.022; SSCV: 0.09
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.912; Size: 1.064; SSCV: 0.084
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 1.043; SSCV: 0.082
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 1.038; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.923; Size: 1.062; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.884; Size: 1.028; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.035; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.92; Size: 1.058; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 1.048; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.872; Size: 1.012; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.882; Size: 1.025; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 1.055; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.91; Size: 1.061; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 1.025; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 1.036; SSCV: 0.082
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.054; SSCV: 0.092
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.044; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 1.046; SSCV: 0.083
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.923; Size: 1.06; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 1.04; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 1.017; SSCV: 0.09
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 1.035; SSCV: 0.081
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.921; Size: 1.085; SSCV: 0.093
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.888; Size: 1.032; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.888; Size: 1.023; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 1.038; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.04; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.888; Size: 1.02; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.055; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 1.067; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.03; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.053; SSCV: 0.084
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.05; SSCV: 0.091
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.907; Size: 1.046; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.034; SSCV: 0.082
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.889; Size: 1.033; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.917; Size: 1.058; SSCV: 0.1
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.912; Size: 1.037; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 1.031; SSCV: 0.09
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 1.02; SSCV: 0.081
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.908; Size: 1.053; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.92; Size: 1.061; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.887; Size: 1.021; SSCV: 0.08
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.908; Size: 1.053; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.913; Size: 1.066; SSCV: 0.084
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 1.045; SSCV: 0.074
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.034; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.919; Size: 1.07; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 1.043; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.049; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.891; Size: 1.023; SSCV: 0.09
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.032; SSCV: 0.09
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 1.035; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 1.047; SSCV: 0.075
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.889; Size: 1.034; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.041; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.907; Size: 1.046; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.91; Size: 1.05; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 1.01; SSCV: 0.07
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.91; Size: 1.047; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.891; Size: 1.034; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.037; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.054; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 1.028; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.03; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 1.016; SSCV: 0.09
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.884; Size: 1.024; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.042; SSCV: 0.081
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.891; Size: 1.028; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 1.036; SSCV: 0.083
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 1.067; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 1.048; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 1.033; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.03; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 1.037; SSCV: 0.074
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.918; Size: 1.052; SSCV: 0.065
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.043; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.882; Size: 1.016; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.052; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.045; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.022; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.882; Size: 1.022; SSCV: 0.073
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.889; Size: 1.032; SSCV: 0.064
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 1.037; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 1.04; SSCV: 0.073
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.899; Size: 1.039; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.908; Size: 1.042; SSCV: 0.081
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.923; Size: 1.075; SSCV: 0.077
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.035; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.055; SSCV: 0.084
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.028; SSCV: 0.069
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 1.018; SSCV: 0.081
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 1.044; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.037; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 1.026; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.047; SSCV: 0.083
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 1.035; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.039; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 1.032; SSCV: 0.072
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.018; SSCV: 0.079
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 1.056; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.049; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.034; SSCV: 0.081
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 1.039; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.888; Size: 1.033; SSCV: 0.075
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.918; Size: 1.054; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 1.037; SSCV: 0.08
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.913; Size: 1.067; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.033; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 1.023; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.884; Size: 1.04; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 1.038; SSCV: 0.083
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.912; Size: 1.057; SSCV: 0.084
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 1.031; SSCV: 0.081
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 1.021; SSCV: 0.071
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.912; Size: 1.056; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.038; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.015; SSCV: 0.09
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.047; SSCV: 0.075
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 1.013; SSCV: 0.069
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.052; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.911; Size: 1.065; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 1.061; SSCV: 0.076
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.92; Size: 1.06; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.038; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 1.045; SSCV: 0.091
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.055; SSCV: 0.075
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 1.041; SSCV: 0.083
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 1.045; SSCV: 0.076
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.879; Size: 1.007; SSCV: 0.082
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.918; Size: 1.044; SSCV: 0.081
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 1.05; SSCV: 0.092
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.918; Size: 1.059; SSCV: 0.083
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 1.03; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.881; Size: 1.004; SSCV: 0.078
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.886; Size: 1.02; SSCV: 0.1
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.889; Size: 1.012; SSCV: 0.069
# Experiment--Data : carer, Score : RAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.912; Size: 1.047; SSCV: 0.083
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 1.117; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 1.081; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 1.125; SSCV: 0.085
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 1.111; SSCV: 0.093
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.89; Size: 1.094; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.119; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.124; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.908; Size: 1.114; SSCV: 0.084
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.869; Size: 1.08; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.116; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.112; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.132; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.913; Size: 1.105; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 1.153; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.895; Size: 1.114; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.875; Size: 1.071; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.932; Size: 1.15; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.883; Size: 1.106; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 1.136; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 1.1; SSCV: 0.084
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.875; Size: 1.094; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.076; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 1.128; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.881; Size: 1.086; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.888; Size: 1.092; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.882; Size: 1.077; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 1.083; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 1.088; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 1.097; SSCV: 0.076
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.909; Size: 1.123; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 1.14; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.858; Size: 1.06; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.896; Size: 1.103; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.121; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.097; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.873; Size: 1.073; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.922; Size: 1.134; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.123; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.102; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.895; Size: 1.073; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.875; Size: 1.074; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.91; Size: 1.092; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.886; Size: 1.085; SSCV: 0.076
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 1.105; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.103; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.125; SSCV: 0.085
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 1.113; SSCV: 0.093
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 1.087; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.918; Size: 1.126; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 1.098; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.915; Size: 1.132; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.127; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.107; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 1.099; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.893; Size: 1.102; SSCV: 0.084
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.916; Size: 1.121; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.923; Size: 1.134; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.866; Size: 1.062; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.91; Size: 1.125; SSCV: 0.093
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 1.113; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.094; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 1.111; SSCV: 0.085
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 1.072; SSCV: 0.083
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.117; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 1.132; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.912; Size: 1.125; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.904; Size: 1.114; SSCV: 0.076
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.902; Size: 1.089; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 1.089; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 1.107; SSCV: 0.093
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.907; Size: 1.147; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.898; Size: 1.092; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.917; Size: 1.13; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.892; Size: 1.146; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.897; Size: 1.101; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.908; Size: 1.113; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 1.124; SSCV: 0.078
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.907; Size: 1.125; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.895; Size: 1.101; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 1.1; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.882; Size: 1.082; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.901; Size: 1.112; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.9; Size: 1.106; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 1.084; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.894; Size: 1.096; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 1.071; SSCV: 0.092
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.911; Size: 1.128; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.906; Size: 1.117; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.885; Size: 1.091; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.903; Size: 1.118; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.905; Size: 1.144; SSCV: 0.087
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.881; Size: 1.086; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.889; Size: 1.092; SSCV: 0.1
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# Coverage: 0.914; Size: 1.142; SSCV: 0.086
# Experiment--Data : carer, Score : SAPS, Predictor : SplitPredictor, Alpha : 0.1
# ...
# Coverage: 0.779; Size: 0.783; SSCV: 0.019
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.713; Size: 0.716; SSCV: 0.047
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.748; Size: 0.751; SSCV: 0.012
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.734; Size: 0.736; SSCV: 0.026
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.753; Size: 0.756; SSCV: 0.007
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.741; Size: 0.742; SSCV: 0.019
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.775; Size: 0.779; SSCV: 0.015
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.753; Size: 0.755; SSCV: 0.007
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.774; Size: 0.777; SSCV: 0.014
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.755; Size: 0.759; SSCV: 0.005
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.759; Size: 0.763; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.791; Size: 0.793; SSCV: 0.031
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.784; Size: 0.786; SSCV: 0.024
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.75; Size: 0.755; SSCV: 0.01
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.773; Size: 0.775; SSCV: 0.013
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.744; Size: 0.748; SSCV: 0.016
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.741; Size: 0.744; SSCV: 0.019
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.717; Size: 0.721; SSCV: 0.043
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.739; Size: 0.744; SSCV: 0.021
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.775; Size: 0.777; SSCV: 0.015
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.761; Size: 0.764; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.811; Size: 0.815; SSCV: 0.051
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.783; Size: 0.786; SSCV: 0.023
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.774; Size: 0.778; SSCV: 0.014
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.796; Size: 0.798; SSCV: 0.036
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.758; Size: 0.76; SSCV: 0.002
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.763; Size: 0.767; SSCV: 0.003
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.743; Size: 0.747; SSCV: 0.017
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.736; Size: 0.74; SSCV: 0.024
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.765; Size: 0.769; SSCV: 0.005
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.765; Size: 0.769; SSCV: 0.005
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.757; Size: 0.762; SSCV: 0.003
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.793; Size: 0.796; SSCV: 0.033
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.748; Size: 0.751; SSCV: 0.012
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.793; Size: 0.798; SSCV: 0.033
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.761; Size: 0.765; SSCV: 0.001
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.736; Size: 0.739; SSCV: 0.024
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.748; Size: 0.751; SSCV: 0.012
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.777; Size: 0.781; SSCV: 0.017
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.773; Size: 0.773; SSCV: 0.013
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.749; Size: 0.751; SSCV: 0.011
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.743; Size: 0.747; SSCV: 0.017
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.767; Size: 0.77; SSCV: 0.007
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.772; Size: 0.776; SSCV: 0.012
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.749; Size: 0.751; SSCV: 0.011
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.774; Size: 0.776; SSCV: 0.014
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.766; Size: 0.767; SSCV: 0.006
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.77; Size: 0.772; SSCV: 0.01
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.772; Size: 0.775; SSCV: 0.012
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.774; Size: 0.778; SSCV: 0.014
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.734; Size: 0.738; SSCV: 0.026
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.756; Size: 0.758; SSCV: 0.004
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.762; Size: 0.765; SSCV: 0.002
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.779; Size: 0.783; SSCV: 0.019
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.791; Size: 0.795; SSCV: 0.031
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.772; Size: 0.775; SSCV: 0.012
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.735; Size: 0.739; SSCV: 0.025
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.713; Size: 0.718; SSCV: 0.047
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.779; Size: 0.784; SSCV: 0.019
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.741; Size: 0.744; SSCV: 0.019
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.727; Size: 0.729; SSCV: 0.033
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.764; Size: 0.767; SSCV: 0.004
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.767; Size: 0.768; SSCV: 0.007
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.775; Size: 0.777; SSCV: 0.015
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.711; Size: 0.712; SSCV: 0.049
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.79; Size: 0.793; SSCV: 0.03
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.76; Size: 0.766; SSCV: 0.0
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.729; Size: 0.732; SSCV: 0.031
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.784; Size: 0.787; SSCV: 0.024
# Experiment--Data : carer, Score : THRRANK, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.761; Size: 0.765; SSCV: 0.001
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.771; Size: 0.876; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.756; Size: 0.848; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.742; Size: 0.816; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.775; Size: 0.864; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.786; Size: 0.884; SSCV: 0.209
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.755; Size: 0.846; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.742; Size: 0.834; SSCV: 0.219
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.726; Size: 0.824; SSCV: 0.218
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.773; Size: 0.86; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.783; Size: 0.869; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.734; Size: 0.826; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.748; Size: 0.845; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.746; Size: 0.82; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.74; Size: 0.846; SSCV: 0.221
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.762; Size: 0.864; SSCV: 0.223
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.764; Size: 0.848; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.743; Size: 0.825; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.774; Size: 0.856; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.738; Size: 0.833; SSCV: 0.22
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.767; Size: 0.862; SSCV: 0.222
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.782; Size: 0.867; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.793; Size: 0.891; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.793; Size: 0.897; SSCV: 0.225
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.763; Size: 0.839; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.816; Size: 0.908; SSCV: 0.224
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.772; Size: 0.867; SSCV: 0.221
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.763; Size: 0.852; SSCV: 0.218
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.776; Size: 0.871; SSCV: 0.22
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.731; Size: 0.827; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.742; Size: 0.821; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.744; Size: 0.833; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.764; Size: 0.86; SSCV: 0.222
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.795; Size: 0.876; SSCV: 0.218
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.768; Size: 0.86; SSCV: 0.223
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.777; Size: 0.869; SSCV: 0.217
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.755; Size: 0.849; SSCV: 0.22
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.736; Size: 0.835; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.778; Size: 0.89; SSCV: 0.225
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.761; Size: 0.845; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.751; Size: 0.839; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.76; Size: 0.84; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.748; Size: 0.85; SSCV: 0.22
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.763; Size: 0.852; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.74; Size: 0.817; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.727; Size: 0.803; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.747; Size: 0.842; SSCV: 0.218
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.786; Size: 0.878; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.794; Size: 0.866; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.769; Size: 0.862; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.72; Size: 0.808; SSCV: 0.215
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.767; Size: 0.852; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.741; Size: 0.833; SSCV: 0.218
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.768; Size: 0.855; SSCV: 0.22
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.739; Size: 0.826; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.78; Size: 0.863; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.735; Size: 0.849; SSCV: 0.223
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.759; Size: 0.85; SSCV: 0.217
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.766; Size: 0.863; SSCV: 0.223
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24
# Coverage: 0.764; Size: 0.866; SSCV: 0.24
# Experiment--Data : carer, Score : APS, Predictor : SplitPredictor, Alpha : 0.24

# %%
colors = plt.get_cmap("tab10")

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24, 6))
names = ['THRRANK', 'APS', 'RAPS', 'SAPS']
# Plot Size vs. Coverage
for idx, score_function in enumerate(score_functions):
    result = results_df[results_df['Score Function'] == names[idx]]
    if score_function == THRRANK:
        ax1.plot(result['Coverage'], result['Size'], color=colors(idx), linestyle='-', marker='o', label="RANK (Ours)")
    else:
        ax1.plot(result['Coverage'], result['Size'], color=colors(idx), linestyle='-', marker='o', label=names[idx])

ax1.set_xlabel('Coverage', fontsize=14)
ax1.set_ylabel('Size', fontsize=14)
ax1.set_title('Size vs. Coverage', fontsize=18)
ax1.legend(loc='upper left', fontsize=14)
ax1.grid(True)

# Plot Coverage vs. Alpha
for idx, score_function in enumerate(score_functions):
    result = results_df[results_df['Score Function'] == names[idx]]
    if score_function == THRRANK:
        ax2.plot(result['Alpha'], result['Coverage'], color=colors(idx), linestyle='-', marker='o', label="RANK (Ours)")
    else:
        ax2.plot(result['Alpha'], result['Coverage'], color=colors(idx), linestyle='-', marker='o', label=names[idx])

# Generate the theoretical line 1 - alpha
theoretical_coverage = [1 - alpha for alpha in alphas]
ax2.plot(alphas, theoretical_coverage, color='black', linestyle='--', label='Theoretical (1 - $\\alpha$)')

ax2.set_xlabel('$\\alpha$', fontsize=14)
ax2.set_ylabel('Coverage', fontsize=14)
ax2.set_title('Coverage vs. $\\alpha$', fontsize=18)
ax2.legend(loc='lower left', fontsize=14)
ax2.grid(True)

# Plot Alpha vs. SSCV
for idx, score_function in enumerate(score_functions):
    result = results_df[results_df['Score Function'] == names[idx]]
    if score_function == THRRANK:
        ax3.plot(result['Alpha'], result['SSCV'], color=colors(idx), linestyle='-', marker='o', label="RANK (Ours)")
    else:
        ax3.plot(result['Alpha'], result['SSCV'], color=colors(idx), linestyle='-', marker='o', label=names[idx])

ax3.set_xlabel('$\\alpha$', fontsize=14)
ax3.set_ylabel('SSCV', fontsize=14)
ax3.set_title('SSCV vs. $\\alpha$', fontsize=18)
ax3.legend(loc='upper left', fontsize=14)
ax3.grid(True)

plt.tight_layout()
plt.show()
fig.savefig('carer.pdf')

# %%
results_df.to_csv('carer.csv')
